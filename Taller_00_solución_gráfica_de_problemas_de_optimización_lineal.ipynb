# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaRamirez8/Fundamentos-de-optimizacion-lineal/blob/main/Taller_00_soluci%C3%B3n_gr%C3%A1fica_de_problemas_de_optimizaci%C3%B3n_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## «*En el fondo de toda gran impotencia encontramos un sentimiento de tranquilidad*».
# ### [Marguerite Yourcenar](https://es.wikipedia.org/wiki/Marguerite_Yourcenar)

# %% [markdown]
# # Taller 00 solución gráfica de problemas de optimización lineal
#
# En este taller se abordará la solución gráfica de problemas de optimización lineal.
#
# Se utilizara la librería: [matplotlib](https://matplotlib.org/) que **no es una librería nativa** de Python por lo que **requiere ser instalada antes de ser invocada**. Sin embargo, esta librería sí está preinstalada en Google Colaboratory por lo que basta invocarla para poder usar sus funcionalidades.

# %% [markdown]
# ## Solución gráfica de un problema de maximización
#
# Resolver el siguiente ejercicio de forma gráfica.
#
# Maximizar Z = 3x + 2y
#
# Sujeto a:
#
# 2x +   y <= 20
#
#  4x + 3y <= 50
#
# x >= 0
#
# y >= 0

# %% [markdown]
# ### Gráfica de las restricciones

# %%
# Importar las librerías requeridas
import numpy as np
import matplotlib.pyplot as plt

"""Generar valores de x para el dominio
     El valor mínimo del dominio es el intercepto con el eje Y y el valor máximo
    del dominio se establece en el menor intercepto de la restriccion con el eje X
"""

# Crear los valores de x
x = np.arange(0, 10.2, 0.1)

# Calcular los valores de y para cada restricción

# Restricción 1
y1 = 20 - 2*x

# Restricción 2
y2 = (50 - 4*x) / 3

# Etiquetar cada uno de los ejes
plt.xlabel('x')
plt.ylabel('y')

# Establecer el título de la gráfica
plt.title('Gráficas de las restricciones')

# Graficar las restricciones
plt.plot(x, y1, label='restricción 1 = 2x + y <= 20')

plt.plot(x, y2, label='restricción 2 = 4x + 3y <= 50')

# Mostrar la leyenda con los nombres de las restricciones
plt.legend()

# Visualizar la cuadrícula de la gráfica
plt.grid(True)

# Mostrar los resultados
plt.show()

# %% [markdown]
# ### Gráfica de las áreas de las restricciones

# %%
# Importar las librerías requeridas
import numpy as np
import matplotlib.pyplot as plt

def min_entre_expresiones(dominio):
    """Calcula el mínimo entre dos expresiones matemáticas para todos los valores
    en el dominio dado.

    Esta función evalúa dos expresiones lineales (y1 y y2) en función de x,
    para cada valor de x en el dominio proporcionado. Luego, determina el valor
    mínimo entre ambas expresiones para cada x y los almacena en una lista.

    Args:
        dominio (list of float or int): Lista de valores de x para los que se
        calcularán y compararán las expresiones y1 y y2.

    Returns:
        list of float: Lista con los valores mínimos de y1 y y2 para cada
        valor de x en el dominio.
    """

    # Lista para almacenar los valores mínimos de las expresiones para cada valor de x
    minimos = []

    for x in dominio:
        # Evaluar la primera expresión en cada valor de x
        y1 = 20 - 2 * x
        # Evaluar la segunda expresión en cada valor de x
        y2 = (50 - 4 * x) / 3
        # Determinar el mínimo entre y1 y y2 y agregarlo a la lista de mínimos
        minimos.append(min(y1, y2))
    return minimos

"""Generar valores de x para el dominio
     El valor mínimo del dominio es el intercepto con el eje Y y el valor máximo
     del dominio se establece en el menor intercepto de la restriccion con el eje X
"""

# Crear los valores de x
x = np.arange(0, 10.2, 0.1)

# Invocar la función para calcular los minimos
min_valor = min_entre_expresiones(x)

# Calcular los valores de y para cada restricción

# Restricción 1
y1 = 20 - 2*x

# Restricción 2
y2 = (50 - 4*x) / 3

# Etiquetar cada uno de los ejes
plt.xlabel('x')
plt.ylabel('y')

# Establecer el título de la gráfica
plt.title('Gráficas de las restricciones del primal')

# Graficar las restricciones
plt.plot(x, y1, label='restricción 1 = 2x + y <= 20')

plt.plot(x, y2, label='restricción 2 = 4x + 3y <= 50')

# Grafica el área entre y1 y y2
plt.fill_between(x, y1, color='blue')
plt.fill_between(x, y2, color='orange')
plt.fill_between(x, min_valor, color='red')

# Ajustar el relleno de la figura para mejorar la visualización
plt.tight_layout()

# Mostrar la leyenda con los nombres de las restricciones
plt.legend()

# Visualizar la cuadrícula de la gráfica
plt.grid(True)

# Mostrar los resultados
plt.show()

# %% [markdown]
# ## Solución gráfica de un problema de minimización
#
# Resolver el siguiente ejercicio de forma gráfica.
#
# Minimizar Z = 20x + 50y
#
# Sujeto a:
#
# 2x + 4y >= 3
#
# x + 3y >= 2
#
# x >= 0
#
# y >= 0

# %% [markdown]
# ### Gráfica de las restricciones

# %%
# Importar las librerías requeridas
import numpy as np
import matplotlib.pyplot as plt

"""Generar valores de x para el dominio
     El valor mínimo del dominio es el intercepto con el eje Y y el valor máximo
     del dominio se establece en el menor intercepto de la restriccion con el eje X
"""

# Crear los valores de x
x = np.arange(0, 1, 0.1)

# Calcular los valores de y para cada restricción

# Definir la primera restricción
y1 = (3 - 2*x) / 4

# Definir la segunda restricción
y2 = (2 - x) / 3

# Etiquetar cada uno de los ejes
plt.xlabel('x')
plt.ylabel('y')

# Establecer el título de la gráfica
plt.title('Gráficas de las restricciones')

# Graficar las restricciones
plt.plot(x, y1, label='restricción 1 = 2x + 4y >= 3')

plt.plot(x, y2, label='restricción 2 = x + 3y >= 2')

# Mostrar la leyenda con los nombres de las restricciones
plt.legend()

# Visualizar la cuadrícula de la gráfica
plt.grid(True)

# %% [markdown]
# ### Gráfica de las áreas de las restricciones

# %%
# Importar las librerías requeridas
import numpy as np
import matplotlib.pyplot as plt

def max_entre_expresiones(dominio):
    """Calcula el máximo entre dos expresiones matemáticas para todos los valores
    en el dominio dado.

    Esta función evalúa dos expresiones lineales (y1 y y2), en función de x,
    para cada valor de x en el dominio proporcionado. Luego, determina el valor
    máximo entre ambas expresiones para cada x y los almacena en una lista.

    Args:
        dominio (list of float or int): Lista de valores de a para los que se
        calcularán y compararán las expresiones y1 y y2.

    Returns:
        list of float: Lista con los valores máximos de y1 y y2 para cada
        valor de x en el dominio.
    """

    # Lista para almacenar los valores máximos de las expresiones para cada valor de a
    maximos = []

    for a in dominio:
        # Evaluar la primera expresión en cada valor de x
        y1 = (3 - 2 * a) / 4
        # Evaluar la segunda expresión en cada valor de x
        y2 = (2 - a) / 3
        # Determinar el máximo entre y1 y y2 y agregarlo a la lista de máximos
        maximos.append(max(y1, y2))

    return maximos

"""Generar valores de x para el dominio
     El valor mínimo del dominio es el intercepto con el eje Y y el valor máximo
     del dominio se establece en el menor intercepto de la restriccion con el eje X
"""

# Crear los valores de x
x = np.arange(0, 1, 0.1)

# Invocar la función para calcular los máximos
max_valor = max_entre_expresiones(x)

# Calcular los valores de y para cada restricción
# Restricción 1
y1 = (3 - 2*x)/4

# Restricción 2
y2 = (2 - x)/3

# Restricción ficticia para crear un «techo» a la gráfica
y3 = (10 - 2*x)/4

# Etiquetar cada uno de los ejes
plt.xlabel('x')
plt.ylabel('y')

# Establecer el título de la gráfica
plt.title('Gráficas de las restricciones')

# Graficar las restricciones
plt.plot(x, y1, label='restricción 1 = 2x + 4y >= 3')

plt.plot(x, y2, label='restricción 2 = 1x + 3y >= 2')

# Graficar el área que cumple la restricción
plt.fill_between(x, y1, y3, color='blue')
plt.fill_between(x, y2, y3, color='orange')
plt.fill_between(x, max_valor, y3, color='red')

# Ajustar el relleno de la figura para mejorar la visualización
plt.tight_layout()

# Mostrar la leyenda con los nombres de las restricciones
plt.legend()

# Visualizar la cuadrícula de la gráfica
plt.grid(True)

# Mostrar los resultados
plt.show()

# %% [markdown]
# # Ejercicios
#
# Resolver los siguientes ejercicios de forma gráfica.

# %% [markdown]
# ## Ejercicio 00
#
# Maximizar  Z: 3x + 2y
#
#    sujeto a:
#
#    2x + y <= 10
#
#    x + 3y <= 12
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
# Resuelva en esta celda el ejercicio
import numpy as np
import matplotlib.pyplot as plt

#Rango de x
x = np.arange(0,5,0.1)

#Restriccion 1
y1=10-2*x

#Restriccion 2
y2=(12-x)/3

#Nombres ejes
plt.xlabel("x")
plt.ylabel("y")

#Titulo grafica
plt.title("Grafica restricciones")

#Graficar restricciones
plt.plot(x,y1,label="restriccion 1 = 2x + y <= 10")
plt.plot(x,y2,label="restriccion 2 = x + 3y <= 12")

#Mostrar leyenda, mostrar cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %%
# Resuelva en esta celda el ejercicio
import numpy as np
import matplotlib.pyplot as plt

#Definir funcion
def min_entre_expresiones(dominio):
  minimos=[]
  for x in dominio:
    #Evalauar las expresiones para cada valor de x
    y1=10-2*x
    y2=(12-x)/3
    #Determinar minimos entre y1 y y2 y agregarlos a la lista
    minimos.append(min(y1,y2))
  return minimos

#Rango de x
x = np.arange(0,5,0.1)

#Invocar funcion
min_valor = min_entre_expresiones(x)

#Restriccion 1
y1=10-2*x

#Restriccion 2
y2=(12-x)/3

#Nombres ejes
plt.xlabel("x")
plt.ylabel("y")

#Titulo grafica
plt.title("Grafica restricciones")

#Graficar restricciones
plt.plot(x,y1,label="restriccion 1 = 2x + y <= 10",color="purple")
plt.plot(x,y2,label="restriccion 2 = x + 3y <= 12",color="lightblue")

#Graficar areas y ajustar relleno
plt.fill_between(x,y1,color="purple")
plt.fill_between(x,y2,color="lightblue")
plt.fill_between(x,min_valor,color="lightgreen")
plt.tight_layout()

#Mostrar leyenda, mostrar cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 01
#
# Minimizar  Z: 2x + 3y
#
#    sujeto a:
#
#    3x + y >= 6
#
#    2x + 2y >= 8
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio (noentiendo)
import numpy as np
import matplotlib.pyplot as plt

#Definir la funcion
def max_entre_expresiones(dominio):
  maximos=[]
  for x in dominio:
    #evaluar las funciones para cada valor de x y determinar el max para la lista
    y1=6-3*x
    y2=(8-2*x)/2
    maximos.append(max(y1,y2))
  return maximos

#Crear valores de x
x = np.arange(0,2.2,0.1)

#Invocar funcion
max_valor =max_entre_expresiones(x)

#Restricciones de y
y1=6-3*x
y2= (8-2*x)/2
y3= (15-x)/2

#Titulos
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica restricciones")

#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = 3x + y >= 6")
plt.plot(x,y2,label="Restriccion 2 = 2x + 2y >= 8")
plt.fill_between(x,y1,y3,color="orange")
plt.fill_between(x,y2,y3,color="blue")
plt.fill_between(x,max_valor,y3,color="red")
plt.tight_layout()

#Mostrar leyenda, cuadricula y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 02
#
# Maximizar  Z: 4x + 3y
#
#    sujeto a:
#
#    3x + 2y <= 15
#
#    2x + 4y <= 12
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def min_entre_expresiones(dominio):
  minimos=[]
  for x in dominio:
    #Evaluar los valores de x para cada y
    y1=(15-3*x)/2
    y2=(12-2*x)/4
    minimos.append(min(y1,y2))
  return minimos
#Rango de x
x=np.arange(0,5,0.1)
#Invocar funcion
min_valor=min_entre_expresiones(x)
#Restricciones
y1=(15-3*x)/2
y2=(12-2*x)/4
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = 3x + 2y <= 15")
plt.plot(x,y2,label="Restriccion 2 = 2x + 4y <= 12")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,color="orange")
plt.fill_between(x,y2,color="blue")
plt.fill_between(x,min_valor,color="red")
plt.tight_layout()
#Mostrar leyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 03
#
# Minimizar  Z: 4x + 2y
#
#    sujeto a:
#
#    x + 3y >= 9
#
#    2x + y >= 8
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio

#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def max_entre_expresiones(dominio):
  maximos=[]
  for x in dominio:
    #Evaluar los valores de x para cada y
    y1=(9-x)/3
    y2=(8-2*x)/2
    maximos.append(max(y1,y2))
  return maximos
#Rango de x
x=np.arange(0,4,0.1)
#Invocar funcion
valor_max=max_entre_expresiones(x)
#Restricciones
y1=(9-x)/3
y2=(8-2*x)/2
y3= (60-x)/9
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + 3y >= 9")
plt.plot(x,y2,label = "Restriccion 2 = 2x + y >= 8")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,y3,color="blue")
plt.fill_between(x,y2,y3,color="orange")
plt.fill_between(x,valor_max,y3,color="red")
#Mostrar leyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 04 **
#
# Maximizar  Z: 5x + 4y
#
#    sujeto a:
#
#    x + y <= 8
#
#    2x + 3y <= 15
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def min_entre_valores(dominio):
  minimos=[]
  for x in dominio:
    y1=8-x
    y2=(15-2*x)/3
    minimos.append(min(y1,y2))
  return minimos
#Rango de x
x=np.arange(0,10,0.1)
#Invocar funcion
min_valor=min_entre_valores(x)
#Restricciones
y1=8-x
y2=(15-2*x)/3
#Nombres ejes y titulo
plt.xlabel("X")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + y <= 8")
plt.plot(x,y2,label="Restriccion 2 = 2x + 3y <= 15")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,color="blue")
plt.fill_between(x,y2,color="orange")
#plt.fill_between(x,min_valor,color="red")
plt.tight_layout()
#Mostrar leyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 05
#
# Minimizar  Z: 3x + 4y
#
#    sujeto a:
#
#    x + 2y >= 5
#
#    2x + y >= 7
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def max_entre_expresiones(dominio):
  maximos=[]
  for x in dominio:
    #Evaluar valores de x para cada y
    y1=(5-x)/2
    y2=(7-2*x)
    maximos.append(max(y1,y2))
  return maximos
#Rango de x
x=np.arange(0,4,0.1)
#Invocar funcion
valor_max=max_entre_expresiones(x)
#Restricciones
y1=(5-x)/2
y2=(7-2*x)
y3= (15-x)/2
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + 2y >= 5")
plt.plot(x,y2,label="Restriccion 2 = 2x + y >= 7")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,y3,color="lightgreen")
plt.fill_between(x,y2,y3,color="lightblue")
plt.fill_between(x,valor_max,y3,color="red")
plt.tight_layout()
#Mostrarleyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 06
#
# Maximizar  Z: 2x + 5y
#
#    sujeto a:
#
#    x + 2y <= 6
#
#    3x + y <= 9
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def min_entre_expresiones(dominio):
  minimos=[]
  for x in dominio:
    #Evaluar los valores de x en cada y
    y1=(6-x)/2
    y2=9-3*x
    minimos.append(min(y1,y2))
  return minimos
#Rango de x
x=np.arange(0,3,0.1)
#Invocar funcion
min_valor=min_entre_expresiones(x)
#Restricciones
y1=(6-x)/2
y2=9-3*x
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + 2y <= 6")
plt.plot(x,y2,label="Restriccion 2 = 3x + y <= 9")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,color="red")
plt.fill_between(x,y2,color="blue")
plt.fill_between(x,min_valor,color="orange")
plt.tight_layout()
#Mostrar leyenda, cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 07
#
# Minimizar  Z: x + 2y
#
#    sujeto a:
#
#    2x + y >= 10
#
#    x + 3y >= 12
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def max_entre_expresiones(dominio):
  maximos=[]
  #evaluar xpara cada y
  for x in dominio:
    y1=10-2*x
    y2=(12-x)/3
    maximos.append(max(y1,y2))
  return maximos
#Rango de x
x=np.arange(0,5,0.1)
#Invocar funcion
valor_max=max_entre_expresiones(x)
#Restricciones
y1=10-2*x
y2=(12-x)/3
y3=(100-x)/9
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de las restricciones")
#Graficar restricciones
plt.plot(x,y1,label=("Restriccion 1 = 2x + y >= 10"))
plt.plot(x,y2,label=("Restriccion 2 = x + 3y >= 12"))
#Graficar area y ajustar relleno
plt.fill_between(x,y1,y3,color="red")
plt.fill_between(x,y2,y3,color="orange")
plt.fill_between(x,valor_max,y3,color="blue")
plt.tight_layout()
#Mostrarleyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 08
#
# Maximizar  Z: x + 3y
#
#    sujeto a:
#
#    x + y <= 5
#
#    2x + 2y <= 10
#
#    x + 2y <= 8
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def min_entre_expresiones(dominio):
  minimos=[]
  for x in dominio:
    y1=5-x
    y2=(10-2*x)/2
    y3=(8-x)/2
    minimos.append(min(y1,y2,y3))
  return minimos
#Rango de x
x=np.arange(0,5,0.1)
#Invocar funcion
min_valor=min_entre_expresiones(x)
#Restricciones
y1=5-x
y2=(10-2*x)/2
y3=(8-x)/2
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + y <= 5",color="red")
plt.plot(x,y2,label="Restriccion 2 = 2x + 2y <= 10",color="orange")
plt.plot(x,y3,label="Restriccion 3 = x + 2y <= 8",color="blue")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,color="red")
plt.fill_between(x,y2,color="orange")
plt.fill_between(x,y3,color="blue")
plt.fill_between(x,min_valor,color="green")
plt.tight_layout()
#Mostrar leyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 09 **
#
# Minimizar  Z: 2x + y
#
#    sujeto a:
#
#    x + y >= 6
#
#    2x + 3y >= 12
#
#    x + 2y >= 8
#
#    x >= 0
#
#    y >= 0

# %%
# Resuelva en esta celda el ejercicio
#Importar librerias
import numpy as np
import matplotlib.pyplot as plt
#Definir funcion
def max_entre_expresiones(dominio):
  maximos=[]
  for x in dominio:
    y1=6-x
    y2=(12-2*x)/3
    y3=(8-x)/2
    maximos.append(max(y1,y2,y3))
  return maximos
#Rango de x
x=np.arange(0,6,0.1)
#Invocar funcion
valor_max=max_entre_expresiones(x)
#Restricciones
y1=6-x
y2=(12-2*x)/3
y3=(8-x)/2
y4=(100-x)/9
#Nombres ejes y titulo
plt.xlabel("x")
plt.ylabel("y")
plt.title("Grafica de restricciones")
#Graficar restricciones
plt.plot(x,y1,label="Restriccion 1 = x + y >= 6",color="red")
plt.plot(x,y2,label="Restriccion 2 = 2x + 3y >= 12",color="orange")
plt.plot(x,y3,label="Restriccion 3 = x + 2y >= 8",color="blue")
#Graficar area y ajustar relleno
plt.fill_between(x,y1,y4,color="red")
plt.fill_between(x,y2,y4,color="orange")
plt.fill_between(x,y3,y4,color="blue")
plt.fill_between(x,valor_max,y4,color="green")
plt.tight_layout()
#Mostrarleyenda,cuadrante y resultados
plt.legend()
plt.grid(True)
plt.show()
